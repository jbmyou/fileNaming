# %%
import os
import shutil
import time
import pandas as pd
from tqdm import tqdm
import re
from pathlib import Path
import file_function as ff

# %%
##### 공백 정리
path = r'C:\Users\SL\Downloads\부산 공유폴더\1.한울가람_헬프\2. 원인서류(대출신청서)\한울 서고2 원장스캔'
ff.change_spaceTo_(path)
# Out:
# 1it [00:01,  1.38s/it]

# %% [markdown]
# ### 채무자키_대상자명 넣기_선정리

# %%
#[시작]##########################################################
# -1...로 넘버링 된거 _(1)..로 변환
path = r'D:\1.다운로드\부산 공유폴더\3. (9008) 더키움자산관리대부_헬프\3. 채권양도통지서\3. 부산발송양통'
os.chdir(path)
file_list = os.listdir(path)
index = 0
p1 = re.compile('[-][\d][.]')

for f in file_list :
    temp = p1.search(f)
    if temp :
        
        new_name = os.path.splitext(f)[0][:-2] + "_("+ temp.group()[1] +")" +os.path.splitext(f)[1]
        os.rename(f, new_name)
        
        index += 1

print(index, "개 완료")
os.chdir('c:/')
#[끝]##########################################################
# Out:
# 2 개 완료

# %%
path = r'C:\Users\SL\Downloads\부산 공유폴더\1.한울가람_헬프\2. 원인서류(대출신청서)\한울 서고2 원장스캔'
f_d = r"C:\Users\SL\Downloads\부산 공유폴더\1.한울가람_헬프\2. 원인서류(대출신청서)\한울 서고2" #폴더내에서 이름 변경시 동일 이름이 존재하게 되면 까다로우니 새 폴더를 만들어서 처리하자. 새폴더

# %%
#[시작]##########################################################
#이미 일련번호 이상하게 붙어버린 거 수정해주자
a = []
os.chdir(path)
file_list = os.listdir(path)
index = 0

for f in file_list:
    new_name = f
    if re.search('_\(\d\)', f) : # 이외의 경우는 이름이 달라지지 않았으므로 아무 작업도 하지 않는다.
        
        new_name = re.sub('_\(\d\)', "", f)
        a.append(f)

        temp = Path(f_d + "/"+ new_name)
        i = 1

        
        while os.path.exists(f_d+"/"+new_name): # os.path는 무조건 경로를 매개변수로..작업디렉토리가 아니므로 풀경로, new_name이 매개변수에 포함되어야 함!
            new_name = temp.stem + "_" +"("+str(i)+")"+temp.suffix
            i += 1
                        
        f_d_final = f_d + "/" + new_name
        shutil.move(f, f_d_final)
        index += 1

print(index)
print(a)
#(1)번이 있는 경우, (2)이 되어야 하는데 (3)이 되어버리는 문제 있음. 그러니 역시 새폴더로 해야 겠다.
#[끝]##########################################################
# Out:
# 0
# []

# %%
#[시작]##########################################################
##맨앞 일련번호와 대상자명 사이에 _ 없는 거 추가 '숫자4개+글자' 또는 '숫자4개-1개+글자'
os.chdir(path)
file_list = os.listdir(path)
_ = '_'
index = 0

for f in file_list:
    # 새 파일명 만들기
    #fullname = Path(Path.cwd() / f)  # 경로+파일명+확장자
    #splitname = fullname.stem.split('_')  # _로 쪼개기(배열)
    #existing_f = f  # f를 살려야 하니 새 변수에
    new_name = f
    
    a = re.match('\d\d\d\d-[\d]{1,}', f)
    b = re.match('\d\d\d\d', f)
    
    if a != None : 
        new_name = a.group() + _ + f[a.span()[1]:]
    elif b != None : 
        new_name = b.group() + _ + f[b.span()[1]:]

    new_name = re.sub('_{2,}', _, new_name)
   
    
    temp = Path(f_d + "/"+ new_name)
    i = 1
    while os.path.exists(f_d+"/"+new_name): # os.path는 무조건 경로를 매개변수로..작업디렉토리가 아니므로 풀경로, new_name이 매개변수에 포함되어야 함!
        new_name = temp.stem + _ +"("+str(i)+")"+temp.suffix
        i += 1
                    
    f_d_final = f_d + "/" + new_name
    os.rename(f, f_d_final)
    index += 1

print(index, "개의 파일 이름 변경 완료")
os.chdir('C:/') # 작업디렉토리 옮겨줘야 폴더 삭제 가능
#[끝]##########################################################
# Out:
# 8 개의 파일 이름 변경 완료

# %%
#[시작]#########################################################################
###### 같은 파일들, 파일명수정한 것만 남기기(기준 : 일련번호와 파일 사이즈)
path = r'C:\Users\SL\Downloads\부산 공유폴더\1.한울가람_헬프\2. 원인서류(대출신청서)\한울 서고2'
os.chdir(path)
file_list = os.listdir(path)
dict = {}
#일련번호 같은데 사이즈 다른 경우
differ_size = []
#일련번호 같은 파일이 두개가 아닌 경우
not2file = {}

numbering = 1
for f in file_list :
    try : 
        if not f.startswith('.') :
            temp = f.split("_",  maxsplit=1) #일련번호와 나머지로 분리
            size = os.path.getsize(f)
            if temp[0] not in dict :
                dict[temp[0]] = [[temp[1], size]]
            else :
                dict[temp[0]].append([temp[1], size]) #일련번호를 key로 하는 딕셔너리 만들기

        dict
        numbering += 1
    except :
        print(numbering)
        print(f) #모든파일에
# Out:
# 2634
# Thumbs.db

# %%
for key, value in dict.items() :
    if len(value) ==2 :
        if value[0][1] == value[1][1] : #두파일의 사이즈 비교
            if len(value[0][0]) > len(value[1][0]) :
                os.remove(key +"_" + value[1][0])
            else :
                os.remove(key +"_" + value[0][0])
        else : #사이즈 같은 것이 없는 경우
            differ_size.append(key+value[0][0])
            differ_size.append(key+value[1][0])
    else :
        num = len(value)
        for i in range(num) :
            if num not in not2file :
                not2file[num] = [key + value[i][0]] #str[num] 안해도 자동으로 바꿔주네
            else :
                not2file[num].append(key + value[i][0])


#[끝]#########################################################################
# Out:
# 사이즈 다름 : ['1738(주)대한디테일_1501000163_112-81-37022.pdf', '1738신영산업.pdf', '2712이현수.pdf', '2712이현수_8102000306_601220-1024010.pdf']
# {3: ['1702-1(주)대영유니콘_1501000256_136-81-01874.pdf', '1702-1대영유니콘.pdf', '1702-1대영유니콘_(1).pdf', '1724-1화인음향(주)_7001000117_137-81-11341.pdf', '1724-1화인음향.pdf', '1724-1화인음향_(1).pdf', '1806(주)한국유량_7001000109_135-81-05858.pdf', '1806최헤원.pdf', '1806한국유량,박영기,김원일.pdf', '3068이덕용.pdf', '3068조남경.pdf', '3068조남경_1501000560_520911-1030711.pdf', '4005여성정밀,천영진,정원국,천일만.pdf', '4005영성정밀(주)_1501000185_613-81-04010.pdf', '4005영성정밀,천영진.pdf', '4018-1구미교역,안데르센가든,신한철,안일문.pdf', '4018-1구미교역,안데르센가든,신한철.pdf', '4018-1안데르센가든(주)_1501000371_109-81-12423.pdf'], 1: ['1714-1대농특수산업(주)_7001000010_105-81-37140.pdf', '1719대농특수산업.pdf', '1720주대섭.pdf', '1724-2화인음향(주)_7001000117_137-81-11341.pdf', '1733신명산업.pdf', '1735영명건설산업.pdf', '1753안영식,서문단,김정근.pdf', '1925-2강기운.pdf', '2142-1동산공영,_유세열,윤관섭.pdf', '2323김규만.pdf', '2324박기일.pdf', '2325이경옥.pdf', '2326김혜리.pdf', '2327이희진.pdf', '2328박상길.pdf', '2329이문희.pdf', '2330김강미.pdf', '2331차길순.pdf', '2332이제학.pdf', '2333금후자.pdf', '2334김애순.pdf', '2335조미선.pdf', '2336김영자.pdf', '2337이명옥.pdf', '2338김임선(우리상사).pdf', '2339고명옥,이찬주,장명월.pdf', '2340송하덕.pdf', '2341김귀덕,권수동,정기주.pdf', '2343천성심,천성미,나정임,김영준.pdf', '2344주호섭.pdf', '2345윤은숙,김영복,안영인.pdf', '2346이기숙.pdf', '2347조흥래.pdf', '2348이상동.pdf', '2349김성자,진영철.pdf', '2350최재분.pdf', '2351김정화.pdf', '2352박순자.pdf', '2353박종훈,이경희,박순용.pdf', '2355서재권,최화자,최춘식.pdf', '2356하원덕,김용부,김순곤.pdf', '2357배성우.pdf', '2358곽은희,곽호암.pdf', '2412-1(주)동산공영_7001000019_112-81-32196.pdf', '2414윤영애.pdf', '2538정승환.pdf', '2737김학례.pdf', '2813김선규.pdf', '2993황선익.pdf', '3271대아,조건제,.pdf', '3406-1대동철강,김석부.pdf', '3406대동철강,김경진,김석부.pdf', '3494이용숙.pdf', '3890허국.pdf', '3954-1한울공영,박상대.pdf', '3954(주)한울공영_1501000192_220-81-05248.pdf', '3966백진무역,현태윤,정강국.pdf', '3970-1기현_1501000231_606-81-56811.pdf', '3980안원준,박정희,오덕환.pdf', '3981이인철,이장웅,이장근,전순종.pdf', '3985(주)동선_1501000434_127-81-09760.pdf', '4005-1영성정밀(주)_1501000185_613-81-04010.pdf', '4018안데르센가든(주)_1501000371_109-81-12423.pdf', '4028-1(주)우정_1501000378_125-81-07937.pdf', '4085-1백진무역(주)_1501000375_213-81-38402.pdf', '4089김동진.pdf', '4091(주)대영실업_1501000285_126-81-09340.pdf', '4094남산개발,김영칠.pdf', '4097영진,김진성.pdf', '4102황옥희.pdf', '4107임헌열,.pdf', '4108추교희.pdf', '4110배태연.pdf', '4112태영공영,차영인.pdf', '4114정혁.pdf', '4115박성진.pdf', '4118디아망뜨.pdf', '4121김윤섭.pdf', '4122최병하(서울이관)_7001004186_661220-1457246.pdf', '4123(주)원영하우징_1902000024_101-81-41166.pdf', '4124허영남_1803000002_680324-1566915.pdf', '4125강상일_1601000135_630715-1222710.pdf', '4126강성준_1601000191_760312-1068517.pdf', '4127고봉민_1601000117_710307-1167519.pdf', '4128권준혁_1601000235_890314-1468511.pdf', '4129김동근_1601000346_890715-1497119.pdf', '4130김은경_1601000340_740922-2231526.pdf', '4131김종찬_1601000078_800214-1065527.pdf', '4132김호성_1601000310_830514-1183716.pdf', '4133남미희_1803000130_940621-2477928.pdf', '4134남철호_1601000195_791203-1813014.pdf', '4135최진경_1803000130_940621-2477928.pdf', '4136한상득_1803000039_621028-1001014.pdf', '4137나동근_1803000120_870113-1095913.pdf', '4138노선임_1803000059_790828-2070216.pdf', '4139박삼석_1803000027_691218-1652421.pdf', '4140서인덕_1803000069_901204-1411412.pdf', '4141박진영_1601000295_850608-2253812.pdf', '4142배철진_1601000413_640507-1123010.pdf', '4143선종찬_1601000284_870116-1036816.pdf', '4144송만석_1601000413_640507-1123010.pdf', '4145송민혁_1601000185_910314-1156849.pdf', '4146송태종_1601000014_860624-1637715.pdf', '4147신구현_1601000042_650127-1357610.pdf', '4148신현일_1601000188_801114-1820411.pdf', '4149안재모_1601000131_580430-1477921.pdf', '4150오재철_1601000304_760120-1531613.pdf', '4151이상우_1601000131_580430-1477921.pdf', '4152이승환_1601000090_661007-1408713.pdf', '4153이충열_1601000040_661005-1068820.pdf', '4154임국일_1601000084_750130-1069614.pdf', '4155임수지_1601000320_890629-2065028.pdf', '4156전태수_1601000179_620607-1474313.pdf', '4157정인식_1601000253_650414-1002319.pdf', '4158정진성_1601000293_780516-1065110.pdf', '4159신서현_1803000017_850416-2032715.pdf', '4160오진국_1803000044_660608-1388215.pdf', '4161이재진(서울이관)_1803000086_730525-1402719.pdf', '4162이재철_1803000041_680319-1396561.pdf', '4163임동선_1803000029_800211-1446823.pdf', '4164김상도_1803000008_700109-1029711.pdf', '4165김병노_1803000129_730123- ...

# %%
# #3개자리 중 사이즈 같은 거 지우는 거 작성중 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# for key, value in dict.items() :
#     if len(value) == 3  :
#         if value[0][1] == value[1][1] : #0,1 파일의 사이즈가 같은 경우
#             differ_size.append(key+value[2][0])
#             if len(value[0][0]) > len(value[1][0]) :
#                 os.remove(key +"_" + value[1][0])
#             else :
#                 os.remove(key +"_" + value[0][0])
#         elif value[0][1] == value[2][1] : #0,2파일의 사이즈가 같은경우
#             differ_size.append(key+value[1][0])
#             if len(value[0][0]) > len(value[2][0]) :
#                 os.remove(key +"_" + value[2][0])
#             else :
#                 os.remove(key +"_" + value[0][0])

#         elif value[1][1] == value[2][1] : #1,2파일의 사이즈가 같은 경우
#             differ_size.append(key+value[0][0])
#             if len(value[1][0]) > len(value[2][0]) :
#                 os.remove(key +"_" + value[2][0])
#             else :
#                 os.remove(key +"_" + value[1][0])

    # else :
    #     num = len(value)
    #     for i in range(num) :
    #         if num not in not2file :
    #             not2file[num] = [key + value[i][0]] #str[num] 안해도 자동으로 바꿔주네
    #         else :
    #             not2file[num].append(key + value[i][0])


##########################################################################

# %%
for x in differ_size :
    print(x)

# %%
#[시작]###########################################################
# 채무자키 있는 애들 추려서 옮기기
path = r'C:\Users\SL\Downloads\부산 공유폴더\1.한울가람_헬프\2. 원인서류(대출신청서)\한울 서고2'
f_d = r'D:\부산 정리\한울가람대부㈜\temp'
os.chdir(path)
file_list = os.listdir(path)
index = 0
p1 = re.compile("\d\d\d\d_\d\d\d\d")

for f in file_list:
    if re.match(p1, f) :
        new_name = f[:4]+f[5:]

        temp = Path(f_d + "/"+ new_name)
        i = 1
        while os.path.exists(f_d+"/"+new_name): # os.path는 무조건 경로를 매개변수로..작업디렉토리가 아니므로 풀경로, new_name이 매개변수에 포함되어야 함!
            new_name = temp.stem + _ +"("+str(i)+")"+temp.suffix
            i += 1
                        
        f_d_final = f_d + "/" + new_name
        shutil.move(f, f_d_final)
        index += 1

print("작업 완료 개수", index)
#[끝]###########################################################
# Out:
# 작업 완료 개수 1

# %%
#[시작]###########################################################
# 사이즈 같은 거 확인
path = r'C:\Users\SL\Downloads\부산 공유폴더\1.한울가람_헬프\2. 원인서류(대출신청서)\한울 서고2'
ff.same_size(path)

#[끝]###########################################################
# Out:
# {7227168: ['1714-1_대농특수산업(주)_7001000010_105-81-37140.pdf', '1719_대농특수산업.pdf'],
#  37761055: ['1724-1_화인음향(주)_7001000117_137-81-11341_(1).pdf',
#   '1724-2_화인음향(주)_7001000117_137-81-11341.pdf'],
#  1724377: ['2040_김동아.pdf', '2040_김동아_7001005438_720518-1392411.pdf'],
#  15700243: ['2142-1_동산공영,_유세열,윤관섭.pdf',
#   '2412-1_(주)동산공영_7001000019_112-81-32196.pdf'],
#  9634420: ['3954-1_한울공영,박상대.pdf', '3954_(주)한울공영_1501000192_220-81-05248.pdf'],
#  27156699: ['3966_백진무역,현태윤,정강국.pdf',
#   '4085-1_백진무역(주)_1501000375_213-81-38402.pdf'],
#  51156740: ['3970-1_기현_1501000231_606-81-56811.pdf',
#   '3981_이인철,이장웅,이장근,전순종.pdf'],
#  12469161: ['4028-1_(주)우정_1501000378_125-81-07937.pdf',
#   '4029_대한기업(주)_1501000247_128-81-04002.pdf']}

# %%
#[시작]###########################################################
#이름과 관리자키 사이에 _ 없는 거 넣기. (코드 실수해서 이름 끝글자 지움...)
path = r'C:\Users\SL\Downloads\부산 공유폴더\1.한울가람_헬프\2. 원인서류(대출신청서)\한울 서고2\새 폴더'
os.chdir(path)
file_list = os.listdir(path)

p1 = re.compile('[0-9]{10}')
for f in file_list :
    splitname = f.split('_')
    if re.search(p1, f) != None :   #관리자키있는것 
        index = re.search(p1, f).start()  
        if f[index-1] != '_' :    #관리자키 직전이 언더바가 아니면
            new_name = f[:index]+"_"+f[index:]    #언더바추가
            os.rename(f, new_name)
#[끝]###########################################################

# %%
#[시작]###########################################################
#위에서 한 실수로 관리자키와 사업번호(주민번호) 합쳐진 거 다시 나누자.
path = r'C:\Users\SL\Downloads\부산 공유폴더\1.한울가람_헬프\2. 원인서류(대출신청서)\한울 서고2'
os.chdir(path)
file_list = os.listdir(path)

p1 = re.compile(r'([\d]{3})-\d\d-\d\d\d\d\d')
p2 = re.compile(r'([\d]{6})-([\d]{6})')

for f in file_list : 
    new_name = ""
    changed = False

    if p1.search(f) : 
        start = p1.search(f).start()
        if f[start-1] != "_" :
            new_name = f[:start] +"_"+f[start:]
            changed = True

    elif p2.search(f) : 
        start = p2.search(f).start()
        if f[start-1] != "_" :
            new_name = f[:start] +"_"+f[start:]
            changed = True

    if changed :
        print(new_name)
        os.rename(f, new_name)



#[끝]###########################################################
# Out:
# 3189_이인숙(_620520-2330529)이윤중,이윤일,이윤조.pdf
# 4183_임종_1803000111_910904-1251244.pdf
# 4184_전대_1803000128_870923-1727217.pdf
# 4185_정슬_1803000121_900227-2415327.pdf
# 4186_정지_1803000055_840905-1169823.pdf
# 4187_정진_1803000085_800316-1029916.pdf
# 4188_차인_1803000053_681129-1067415.pdf
# 4189_남광산업개발㈜_1501000035_123-81-33064.pdf
# 4190_엄학_1901000057_590313-1901918.pdf
# 4191_김화_1603000048_680104-2851610.pdf
# 4192_황연_1603000002_760326-2475721.pdf
# 4193-1_강지_1602000002_841218-2069214.pdf
# 4193-2_강지_1602000003_841218-2069214.pdf
# 4193_강지_1602000001_841218-2069214.pdf
# 4194_마트랜드㈜_1902000037_133-81-40859.pdf
# 4195_김기_1602000012_800223-1716116.pdf
# 4196_화평국제무역㈜_1902000056_210-81-41306.pdf
# 4197_김민_1602000108_810418-1042020.pdf
# 4198_박경_1602000120_740818-2226115.pdf
# 4199_송병_1602000113_770104-1113115.pdf
# 4200_신도_1602000127_830311-1009315.pdf
# 4201_신현_1602000054_830831-1229028.pdf
# 4202_이남_1602000064_810820-1002115.pdf
# 4203_이남_1602000065_810820-1002115.pdf
# 4204_이원_1602000071_830505-1055511.pdf
# 4205_임영_1602000083_791225-1064126.pdf
# 4206_정지_1602000094_860215-1621635.pdf
# 4207_지재영(변경전지상용_1602000096_691207-1117210.pdf
# 4208_홍정민(홍영표_변경전_1902000158_580623-1402722.pdf
# 4209_이미대_1501001361_410607-2029812.pdf
# 4210_노순_1902000082_650510-1932513.pdf

# %%
#[시작]###########################################################
#(주)는 ㈜로 바꾸고 넘버링 제외한 괄호 다 지우기
path = r'C:\Users\SL\Downloads\부산 공유폴더\1.한울가람_헬프\2. 원인서류(대출신청서)\한울 서고2'
_ = "_"
os.chdir(path)
file_list = os.listdir(path)

p1 = re.compile('\(주\)|\(주')
p2 = re.compile('\([\D]+\)') 
for f in file_list :
        
    changed = False
    #new_name = "" #이거 안 해서 (주)그냥 다 빠져버렸네. ;; 어차피 지우고 검색할 거니까.. 

    if p1.search(f) :
        new_name = p1.sub("㈜", f)
        changed = True

    if p2.search(f) : #괄호 사이에 공백 있었으면 f1에 다 안 담기므로
        new_name = p2.sub("", f)
        changed = True
    
    if changed :
        os.rename(f, new_name)

os.chdir('C:/')

# %% [markdown]
# ### 채무자키_대상자명 넣기

# %%
## 참조 df 불러오기 ~~~~ trim()함수로 앞뒤공백만 제거 ~~~~
## 참조할 col_name = '채무자키', '매각사구분', 성명', '주민번호', '매각사', '보증인성명'
                ###################
sell_company = "대산대부"
                ###################
df_c = pd.read_excel(r'C:\Users\SL\Desktop\채무자조회.xlsx')
df_c = df_c[df_c.매각사==sell_company]   # df_c.loc[조건,:] 이렇게 안 해도 성능차이 없이 되네!!
df_c.head()
# Out:
#          채무자키 매각사구분   성명            주민번호  성별   매각사 회생사건결과       관리자기타 보증인성명  \
# 467  20426582    대산  강기원  750626-2932126  여자  대산대부    NaN  9006000019   NaN
# 513  20407845    대산  강단향  780301-2916613  여자  대산대부    NaN  9006000419   강민정
# 514  20407847    대산  강단향  780301-2916613  여자  대산대부    NaN  9006000601   강민정
# 571  20408877    대산  강동수  650427-1120617  남자  대산대부    NaN  9006000478   강수경
# 607  20426711    대산  강두은  700917-2121013  여자  대산대부    NaN  9006000218   김양남
#
#     변경전성명 변경전주민번호  보증인수 파산사건결과
# 467   NaN     NaN     0    NaN
# 513   NaN     NaN     1    NaN
# 514   NaN     NaN     1    NaN
# 571   NaN     NaN     1    NaN
# 607   NaN     NaN     1    NaN

# %%
path = r'D:\1.다운로드\부산 공유폴더\5. (9006) 대산대부(태산)_헬프\1. 채권양도통지서\대산대부-차주'
f_d = r'D:\부산 정리\대산대부'
docu_kind = '양도통지서'

#etc = ["재도", "확정증명원", "보증인"] #키워드 있는 경우
etc_str = "" #_보증인" #언더바 붙여야 돼!!!! 키워드 없는 경우, 폴더도 없다면(주채무자인경우) ""로 처리

# %%
os.chdir(path)
file_list = os.listdir(path)
_ = '_'
index = 0
###### 빈리스트로 나올거라 생각하지만 혹시나
admin_duple = []
debtor_duple = []
no_search = []
############################################
f = ""
p1 = re.compile(r'([\d]{3})-\d\d-\d\d\d\d\d')
p2 = re.compile(r'([\d]{6})-([\d]{6})')
# 앞에 4자리가 같은 것끼리 세트로 묶고 그중에 관리자키 있는 거로 채무자키 찾아서 ~

# try :
    
for f in file_list : 
    if f != "Thumbs.db" :
        fullname = Path(Path.cwd() / f)  # 경로+파일명+확장자
        splitname = fullname.stem.split('_')  # 확장자 제외하고 _로 쪼개기(배열)
        
        changed = False

        if (re.search('[0-9]{10}', f) != None) & (re.search('[0-9]{11,}', f) == None) : #관리자키 있으면
            admin = re.search('[0-9]{10}', f).group()
            df_ = df_c[df_c.관리자기타==admin]     # 참조df에서 관리자키 일치하는 거 찾아서
            if len(df_.index)==1 :                # 일치하는 게 하나만 나왔을 때
                splitname[0] = str(df_.채무자키.iloc[0])     # 맨 앞자리를 채무자키로 대체
                splitname[1] = str(df_.성명.iloc[0])    #인덱싱 결과는 시리즈이기 때문에 .iloc[0]붙여야
                changed = True
            elif len(df_.index)>1 :
                admin_duple.append(f)           # 일치값이 여러개나오면 별도 리스트로
            else :
                no_search.append(f)             # 일치값이 없을 때
        

        elif (p1.search(f) != None) | (p2.search(f) != None) :   # 관리자키 없으면 사업자번호 / 주민번호로 찾자
            if p1.search(f) != None :
                number = p1.search(f).group()
            else :
                number = p2.search(f).group()

            df_ = df_c[df_c.주민번호==number]
            if len(df_.index) ==1:
                splitname[0] = str(df_.채무자키.iloc[0])
                splitname[1] = str(df_.성명.iloc[0])
                changed = True
            elif len(df_.index) >1 :
                admin_duple.append(f)           
            else :
                no_search.append(f)
        
        else : #관리자키도 주민번호도 없으면 이름으로
            name = splitname[1]
            df_ = df_c[df_c.성명.str.contains(name)]
            if len(df_) ==1 :
                splitname[0] = str(df_.채무자키.iloc[0])
                splitname[1] = str(df_.성명.iloc[0])
                changed = True
            elif len(df_.index) >1 :
                admin_duple.append(f)           
            else :
                no_search.append(f)



        # 파일명 바꾸고 이동하기
        if changed : #채무자키 정상 입력 된 경우
            new_name = splitname[0]+_+splitname[1]+_+docu_kind+fullname.suffix

            temp = Path(f_d + "/"+ new_name)
            i = 1
            
            while os.path.exists(f_d+"/"+new_name): # os.path는 무조건 경로를 매개변수로..작업디렉토리가 아니므로 풀경로, new_name이 매개변수에 포함되어야 함!
                new_name = temp.stem + _ +"("+str(i)+")"+temp.suffix
                i += 1
                            
            f_d_final = f_d + "/" + new_name
            shutil.move(f, f_d_final)
            index += 1

# except Exception as e:
#     print(f)
#     print(e)
#     print(index,"개 파일 이동 완료")
#     print("중복키", len(admin_duple))
#     print("키없음", len(no_search))

print("완료")
print(index,"개 파일 이동 완료")
print("중복키", len(admin_duple))
print("키없음", len(no_search))
os.chdir("c:/")


#1)관리자키 있으면 관리자키로 검색 -> 채무자키 하나 검색됐으면 0번 자리를 채무자키로 대신 // 하나 이상이면? 일단 관리자키 리스트 만들어 저장
#2)관리자키 없으면 대상자명 검색 -> 채무자키 하나 검색됐으면 0번 자리를 채무자키로 대신  // 하나 이상이면? 양이 얼마나 되는지 보게 일단 대상자명 리스트 만들어 저장
#3)일치하는 값이 둘다 없다면 -> 참조없음 리스트 만들어 저장

# %%
###########[시작]관리자번호만 있는 경우################
os.chdir(path)
file_list = os.listdir(path)
_ = '_'
index = 0
###### 빈리스트로 나올거라 생각하지만 혹시나
admin_duple = []
debtor_duple = []
no_search = []
############################################
f = ""
p1 = re.compile(r'([\d]{3})-\d\d-\d\d\d\d\d')
p2 = re.compile(r'([\d]{6})-([\d]{6})')
# 앞에 4자리가 같은 것끼리 세트로 묶고 그중에 관리자키 있는 거로 채무자키 찾아서 ~

# try :
    
for f in file_list : 
    if f != "Thumbs.db" :
        fullname = Path(Path.cwd() / f)  # 경로+파일명+확장자
        splitname = [None]*2
        changed = False

        if (re.search('[0-9]{10}', f) != None) & (re.search('[0-9]{11,}', f) == None) : #관리자키 있으면
            admin = re.search('[0-9]{10}', f).group()
            df_ = df_c[df_c.관리자기타==admin]     # 참조df에서 관리자키 일치하는 거 찾아서
            if len(df_.index)==1 :                # 일치하는 게 하나만 나왔을 때
                splitname[0] = str(df_.채무자키.iloc[0])     # 맨 앞자리를 채무자키로 대체
                
                ### 주채무자 vs 보증인
                # 1)주채무자 
                splitname[1] = str(df_.성명.iloc[0])    #인덱싱 결과는 시리지이기 때문에 .iloc[0]붙여야
                 
                # 2)보증인 폴더
                #splitname[1] = str(df_.보증인성명.iloc[0])
                
                # 3)보증인 키워드 & 추가 기타정보 검색해야 할 때
                # for e in etc :
                #     if re.search(e, f):
                #         etc_str += ( _ + e )
                #         splitname[1] = str(df_.보증인성명.iloc[0])
                                                
                changed = True
                
            elif len(df_.index)>1 :
                admin_duple.append(f)           # 일치값이 여러개나오면 별도 리스트로
            else :
                no_search.append(f)             # 일치값이 없을 때


        # 파일명 바꾸고 이동하기 - temp.stem은 넘버링이 붙지 않은 상태이므로 _(1)_(1) 이런 문제가 없다.
        if changed : #채무자키 정상 입력 된 경우
            new_name = splitname[0]+_+splitname[1]+_+docu_kind+ etc_str +fullname.suffix

            temp = Path(f_d + "/"+ new_name)
            i = 1
            
            while os.path.exists(f_d+"/"+new_name): # os.path는 무조건 경로를 매개변수로..작업디렉토리가 아니므로 풀경로, new_name이 매개변수에 포함되어야 함!
                new_name = temp.stem + _ +"("+str(i)+")"+temp.suffix
                i += 1
                            
            f_d_final = f_d + "/" + new_name
            shutil.move(f, f_d_final)
            index += 1

# except Exception as e:
#     print(f)
#     print(e)
#     print(index,"개 파일 이동 완료")
#     print("중복키", len(admin_duple))
#     print("키없음", len(no_search))

print("완료")
print(index,"개 파일 이동 완료")
print("중복키", len(admin_duple))
print("키없음", len(no_search))
os.chdir("c:/")

###########[끝]관리자번호만 있는 경우################
# Out:
# 완료
# 571 개 파일 이동 완료
# 중복키 0
# 키없음 0

# %%
path = r'D:\부산 정리\KB국민카드'
os.chdir(path)
file_list = os.listdir(path)
p1 = re.compile('양도통지서1차')
for f in file_list :
    if p1.search(f) :
        new_name = p1.sub("양도통지서_1차", f)
        os.rename(f, path + "/" + new_name)

# %%
print("중복키", len(admin_duple))
print(admin_duple)
print("키없음", len(no_search))
print(no_search)
# Out:
# 중복키 0
# []
# 키없음 4
# ['20408195_안선이,이정인_원인서류.pdf', '가순광_약정서.pdf', '김양호_대출원장.pdf', '김현상_원장.pdf']

# %%
splitname = ['2458', '포스기술㈜']
f = ["㈜123456㈜78901㈜", "포스기술(주)"]
df = pd.DataFrame(f, columns= ['성명'])
splitname[1] = re.sub('㈜',"",splitname[1]) #㈜있으면 제거
print(splitname[1])
df_debtor = df[df.성명.str.contains(splitname[1])]       # 이름으로 검색
df_debtor

#f = re.sub('㈜',"",f)
# Out:
# 포스기술
#         성명
# 1  포스기술(주)

# %%
#[시작]###########################################################
#후처리 : 한울가람 앞에 넣고, 원인서류 뒤에 넣고

path = r'C:\Users\SL\Downloads\부산 공유폴더\1.한울가람_헬프\2. 원인서류(대출신청서)\한울 서고2'
kind1 = '한울가람_'
kind2 = '_원인서류'

file_list = os.listdir(path)
f = ""
try :
    for f in file_list :
        if f != "Thumbs.db" :
            new_name = kind1 + os.path.splitext(f)[0] + kind2 + os.path.splitext(f)[1]
            os.rename(path + "/" + f, path + "/" + new_name)

except Exception as e:
    print(e)
    print(f)
#[끝]###########################################################
